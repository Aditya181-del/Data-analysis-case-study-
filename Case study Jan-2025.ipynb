# %%
#Importing necessary libraries. 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the dataset. 
df = pd.read_csv(r"C:\Users\adity\Downloads\Inteelipat course\commodity_prices.csv")
df
# Out:
#      Unnamed: 0        date  oil_brent  oil_dubai  coffee_arabica  \
# 0             1  01-01-1960       1.63       1.63        0.940900
# 1             2  01-02-1960       1.63       1.63        0.946900
# 2             3  01-03-1960       1.63       1.63        0.928100
# 3             4  01-04-1960       1.63       1.63        0.930300
# 4             5  01-05-1960       1.63       1.63        0.920000
# ..          ...         ...        ...        ...             ...
# 751         752  01-08-2022      98.60      97.75        5.917861
# 752         753  01-09-2022      90.16      90.63        5.897138
# 753         754  01-10-2022      93.13      90.59        5.292852
# 754         755  01-11-2022      91.07      86.28        4.715462
# 755         756  01-12-2022      80.90      76.78        4.629482
#
#      coffee_robustas  tea_columbo  tea_kolkata  tea_mombasa  sugar_eu  \
# 0           0.696864     0.930301     1.121401     1.037400  0.122356
# ...

# %%
#Dataset information. 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       756 non-null    int64
#  1   date             756 non-null    object
#  2   oil_brent        756 non-null    float64
#  3   oil_dubai        756 non-null    float64
#  4   coffee_arabica   756 non-null    float64
#  5   coffee_robustas  756 non-null    float64
#  6   tea_columbo      756 non-null    float64
#  7   tea_kolkata      756 non-null    float64
#  8   tea_mombasa      756 non-null    float64
#  9   sugar_eu         756 non-null    float64
#  10  sugar_us         756 non-null    float64
#  11  sugar_world      756 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 71.0+ KB

# %%
#For checking the number of rows and columns.
df.shape
# Out:
# (756, 12)

# %%
#First five records in the dataset.
df.head()
# Out:
#    Unnamed: 0        date  oil_brent  oil_dubai  coffee_arabica  \
# 0           1  01-01-1960       1.63       1.63          0.9409
# 1           2  01-02-1960       1.63       1.63          0.9469
# 2           3  01-03-1960       1.63       1.63          0.9281
# 3           4  01-04-1960       1.63       1.63          0.9303
# 4           5  01-05-1960       1.63       1.63          0.9200
#
#    coffee_robustas  tea_columbo  tea_kolkata  tea_mombasa  sugar_eu  sugar_us  \
# 0         0.696864     0.930301     1.121401       1.0374  0.122356  0.116845
# 1         0.688707     0.930301     1.121401       1.0374  0.122356  0.119049
# 2         0.688707     0.930301     1.121401       1.0374  0.122356  0.121254
# 3         0.684519     0.930301     1.121401       1.0374  0.122356  0.123459
# 4         0.690692     0.930301     1.121401       1.0374  0.122356  0.121254
#
#    sugar_world
# 0       0.0666
# 1       0.0679
# 2       0.0683
# 3       0.0681
# 4       0.0683

# %%
#Last 5 record in the data set. 
df.tail()
# Out:
#      Unnamed: 0        date  oil_brent  oil_dubai  coffee_arabica  \
# 751         752  01-08-2022      98.60      97.75        5.917861
# 752         753  01-09-2022      90.16      90.63        5.897138
# 753         754  01-10-2022      93.13      90.59        5.292852
# 754         755  01-11-2022      91.07      86.28        4.715462
# 755         756  01-12-2022      80.90      76.78        4.629482
#
#      coffee_robustas  tea_columbo  tea_kolkata  tea_mombasa  sugar_eu  \
# 751         2.417366     4.210000     3.538154     2.360000  0.330773
# 752         2.455065     4.490000     3.153198     2.360000  0.323621
# 753         2.270979     4.135621     2.833112     2.457500  0.320943
# 754         2.041258     3.831528     2.849979     2.490000  0.332993
# 755         2.045446     3.994073     2.421516     2.386667  0.345729
#
#      sugar_us  sugar_world
# 751  0.782199     0.393525
# 752  0.770956     0.390659
# 753  0.762578     0.386911
# 754  0.792340     0.407414
# ...

# %%
#The detailed description of all the columns.
df.describe()
# Out:
#        Unnamed: 0   oil_brent   oil_dubai  coffee_arabica  coffee_robustas  \
# count  756.000000  756.000000  756.000000      756.000000       756.000000
# mean   378.500000   32.724944   31.238130        2.576555         1.727478
# std    218.382692   31.885368   30.936611        1.342454         0.940748
# min      1.000000    1.210000    1.210000        0.777600         0.487210
# 25%    189.750000   10.564999   10.452500        1.351625         0.923053
# 50%    378.500000   20.489130   18.550000        2.697794         1.632172
# 75%    567.250000   47.157500   45.576023        3.312950         2.282200
# max    756.000000  133.873043  131.224783        7.003600         6.883547
#
#        tea_columbo  tea_kolkata  tea_mombasa    sugar_eu    sugar_us  \
# count   756.000000   756.000000   756.000000  756.000000  756.000000
# mean      1.777962     1.870308     1.671222    0.405158    0.432462
# std       1.008679     0.697867     0.615357    0.187741    0.188589
# ...

# %%
#There are no null values in the dataset.
df.isna().sum()
# Out:
# Unnamed: 0         0
# date               0
# oil_brent          0
# oil_dubai          0
# coffee_arabica     0
# coffee_robustas    0
# tea_columbo        0
# tea_kolkata        0
# tea_mombasa        0
# sugar_eu           0
# sugar_us           0
# sugar_world        0
# dtype: int64

# %%
#There are no duplicated columns.
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Maximum prices of all the columns.
max = df.max()
max
# Out:
# Unnamed: 0                756
# date               01-12-2022
# oil_brent          133.873043
# oil_dubai          131.224783
# coffee_arabica         7.0036
# coffee_robustas      6.883547
# tea_columbo              4.49
# tea_kolkata          4.073011
# tea_mombasa            3.3925
# sugar_eu             0.783171
# sugar_us             1.263247
# sugar_world            1.2377
# dtype: object

# %%
#Minimum prices of all the columns. 
min = df.min()
min
# Out:
# Unnamed: 0                  1
# date               01-01-1960
# oil_brent                1.21
# oil_dubai                1.21
# coffee_arabica         0.7776
# coffee_robustas       0.48721
# tea_columbo          0.434198
# tea_kolkata          0.664799
# tea_mombasa            0.7196
# sugar_eu             0.112215
# sugar_us             0.116845
# sugar_world            0.0287
# dtype: object

# %%
#Total sum of sales of all columns since 1960-01-01 to 2022-12-01.	
df.sum()
# Out:
# Unnamed: 0                                                    286146
# date               01-01-196001-02-196001-03-196001-04-196001-05-...
# oil_brent                                               24740.057761
# oil_dubai                                               23616.026205
# coffee_arabica                                           1947.875425
# coffee_robustas                                          1305.973633
# tea_columbo                                              1344.138955
# tea_kolkata                                              1413.952969
# tea_mombasa                                              1263.443497
# sugar_eu                                                  306.299221
# sugar_us                                                  326.941411
# sugar_world                                               181.639139
# dtype: object

# %%
#1. What is the maximum price of Robusta coffee ?
df['coffee_robustas'].max()
# Out:
# np.float64(6.883547)

# %%
#2. What is the 75th percentile of sugar prices in the European Union (EU)?
np.percentile(df['sugar_eu'],75)
# Out:
# np.float64(0.56951937975)

# %%
#3. What is the skewness of the price distribution for Arabica coffee?
from scipy.stats import skew
df['coffee_arabica'].skew()
# Out:
# np.float64(0.5903976942863646)

# %%
#4. Is the distribution of sugar prices in the US significantly different from a normal distribution?
x = df['sugar_us']
y = df['sugar_world']
plt.scatter(x,y,color = 'Red')
plt.title("Comparision of sugar USA to world")
plt.xlabel("Sugar_US")
plt.ylabel("Sugar_world")
plt.show()

# %%
#What is the overall price trend for each commodity ?
# Line chart to check the trends over time. 
fig = plt.subplots(2,2,figsize = (20,10))
plt.subplot(2,2,1)
plt.plot(df['coffee_arabica'],label = 'coffee robustas price',color = 'Blue')
plt.title("Coffee Arabica trend")
plt.ylabel("Price")
plt.xlabel("Time")
plt.legend()


plt.subplot(2,2,2)
plt.plot(df['coffee_robustas'],label = 'coffee dubai price',color = 'Red')
plt.title("Coffee Robustas trend")
plt.ylabel("Price")
plt.xlabel("Time")
plt.legend()


plt.subplot(2,2,3)
plt.plot(df['oil_brent'],label = 'Oil brent price',color = 'Orange')
plt.title("Oil brent trend")
plt.ylabel("Price")
plt.xlabel("Time")
plt.legend()

plt.subplot(2,2,4)
plt.plot(df['oil_dubai'],label = 'Oil dubai price',color = 'Green')
plt.title("Oil dubai trend")
plt.ylabel("Price")
plt.xlabel("Time")
plt.legend()
plt.show()

# %%
#Hist plots for checking price distribution.
fig = plt.subplots(2,2,figsize = (20,10))
plt.subplot(2,2,1)
plt.hist(df['tea_columbo'],color = 'goldenrod',bins=30,edgecolor = 'black')
plt.title("Tea Columbo price distribution")
plt.ylabel("Price")
plt.xlabel("Time")

plt.subplot(2,2,2)
plt.hist(df['tea_kolkata'],color = 'Grey',bins=30,edgecolor = 'black')
plt.title("Tea Kolkata price distribution")
plt.ylabel("Price")
plt.xlabel("Time")

plt.subplot(2,2,3)
plt.hist(df['tea_mombasa'],color = '#3498DB',bins=30,edgecolor = 'black')
plt.title("Tea Mombasa price distribution")
plt.ylabel("Price")
plt.xlabel("Time")

plt.subplot(2,2,4)
plt.hist(df['sugar_eu'],color = 'maroon',bins=30,edgecolor = 'black')
plt.title("Sugar Europe price distribution")
plt.ylabel("Price")
plt.xlabel("Time")
plt.show()

# %%
#Line plots to check the time series of USA prices
fig = plt.subplots(2,2,figsize = (20,10))
plt.subplot(2,2,1)
sns.lineplot(data=df,x='date', y='sugar_us', color='#a52a2a')
plt.title('Time Series of Sugar USA Prices')

plt.subplot(2,2,2)
sns.lineplot(data=df,x='date', y='sugar_world', color='#2e8b57')
plt.title('Time Series of Sugar World Prices')

plt.subplot(2,2,3)
sns.lineplot(data=df,x='date', y='coffee_arabica', color='#ffa500')
plt.title('Time Series of Coffee Arabica Prices')

plt.subplot(2,2,4)
sns.lineplot(data=df,x='date', y='oil_brent', color='#00008b')
plt.title('Time Series of Oil brent Prices')
plt.show()

# %%
#Scatter plots for comparing all the columns 
fig = plt.subplots(2,5,figsize=(20,8))
plt.subplot(2,5,1)
plt.scatter(df.index, df['sugar_world'], color='#6a4c93')
plt.title('Scatter Plot of Sugar World Prices')
plt.xlabel('Index')
plt.ylabel('Price')

plt.subplot(2,5,2)
plt.scatter(df.index, df['sugar_us'], color='#ff6361')
plt.title('Scatter Plot of Sugar USA Prices')
plt.xlabel('Index')
plt.ylabel('Price')

plt.subplot(2,5,3)
plt.scatter(df.index, df['sugar_eu'], color='#f95d6a')
plt.title('Scatter Plot of Sugar Europe Prices')
plt.xlabel('Index')
plt.ylabel('Price')

plt.subplot(2,5,4)
plt.scatter(df.index, df['tea_mombasa'], color='#58508d')
plt.title('Scatter Plot of Tea Mombasa Prices')
plt.xlabel('Index')
plt.ylabel('Price')

plt.subplot(2,5,5)
plt.scatter(df.index, df['tea_kolkata'], color='#bc5090')
plt.title('Scatter Plot of Tea Kolkata Prices')
plt.xlabel('Index')
plt.ylabel('Price')

plt.subplot(2,5,6)
plt.scatter(df.index, df['tea_columbo'], color='#ffa07a')
plt.title('Scatter Plot of Tea Colombo Prices')
plt.xlabel('Index')
plt.ylabel('Price')

plt.subplot(2,5,7)
plt.scatter(df.index, df['coffee_robustas'], color='#17becf')
plt.title('Scatter Plot of Coffee Robustas Prices')
plt.xlabel('Index')
plt.ylabel('Price')

plt.subplot(2,5,8)
plt.scatter(df.index, df['coffee_arabica'], color='#ef5675')
plt.title('Scatter Plot of Coffee Arabica Prices')
plt.xlabel('Index')
plt.ylabel('Price')

plt.subplot(2,5,9)
plt.scatter(df.index, df['oil_dubai'], color='#bcbd22')
plt.title('Scatter Plot of Oil Dubai Prices')
plt.xlabel('Index')
plt.ylabel('Price')

plt.subplot(2,5,10)
plt.scatter(df.index, df['oil_brent'], color='#003f5c')
plt.title('Scatter Plot of Oil barent Prices')
plt.xlabel('Index')
plt.ylabel('Price')

plt.subplots_adjust(
    wspace=0.3,  
    hspace=0.5  
)
plt.show()

# %%
#Checking for outliers
fig = plt.subplots(2,5,figsize=(20,8))
plt.subplot(2,5,1)
sns.boxplot(data=df['coffee_arabica'], color='#003f5c', showfliers=True, linewidth=2.5)
plt.title("Box plot of Coffee arabica")
plt.xlabel("Variables", fontsize=14)
plt.ylabel("Values", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)  

plt.subplot(2,5,2)
sns.boxplot(data=df['coffee_robustas'], color='#bcbd22', showfliers=True, linewidth=2.5)
plt.title("Box plot of Coffee Robustas")
plt.xlabel("Variables", fontsize=14)
plt.ylabel("Values", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)  

plt.subplot(2,5,3)
sns.boxplot(data=df['oil_brent'], color='#ef5675', showfliers=True, linewidth=2.5)
plt.title("Box plot of Oil Brent")
plt.xlabel("Variables", fontsize=14)
plt.ylabel("Values", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)  

plt.subplot(2,5,4)
sns.boxplot(data=df['oil_dubai'],color='#17becf', showfliers=True, linewidth=2.5)
plt.title("Box plot of Oil dubai")
plt.xlabel("Variables", fontsize=14)
plt.ylabel("Values", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)  

plt.subplot(2,5,5)
sns.boxplot(data=df['sugar_eu'], color='#ffa07a', showfliers=True, linewidth=2.5)
plt.title("Box plot of Sugar Europe")
plt.xlabel("Variables", fontsize=14)
plt.ylabel("Values", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)  

plt.subplot(2,5,6)
sns.boxplot(data=df['sugar_us'], color= '#bc5090', showfliers=True, linewidth=2.5)
plt.title("Box plot of Sugar US")
plt.xlabel("Variables", fontsize=14)
plt.ylabel("Values", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)  

plt.subplot(2,5,7)
sns.boxplot(data=df['sugar_world'], color='#58508d', showfliers=True, linewidth=2.5)
plt.title("Box plot of Sugar World")
plt.xlabel("Variables", fontsize=14)
plt.ylabel("Values", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)  


plt.subplot(2,5,8)
sns.boxplot(data=df['tea_columbo'], color='#f95d6a', showfliers=True, linewidth=2.5)
plt.title("Box plot of Tea Columbo")
plt.xlabel("Variables", fontsize=14)
plt.ylabel("Values", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)  

plt.subplot(2,5,9)
sns.boxplot(data=df['tea_kolkata'], color='#2ca02c', showfliers=True, linewidth=2.5)
plt.title("Box plot of Tea Kolkata")
plt.xlabel("Variables", fontsize=14)
plt.ylabel("Values", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)  

plt.subplot(2,5,10)
sns.boxplot(data=df['tea_mombasa'], color='#6a4c93', showfliers=True, linewidth=2.5)
plt.title("Box plot of Tea Mombasa")
plt.xlabel("Variables", fontsize=14)
plt.ylabel("Values", fontsize=14)
plt.grid(axis="y", linestyle="--", alpha=0.7)  
plt.tight_layout()
plt.show()

# %%
#Converting the non-numeric columns which is necessary for heatmap
numeric_df = df.select_dtypes(include='number')
numeric_df = numeric_df.fillna(0)  
numeric_df
# Out:
#      Unnamed: 0  oil_brent  oil_dubai  coffee_arabica  coffee_robustas  \
# 0             1       1.63       1.63        0.940900         0.696864
# 1             2       1.63       1.63        0.946900         0.688707
# 2             3       1.63       1.63        0.928100         0.688707
# 3             4       1.63       1.63        0.930300         0.684519
# 4             5       1.63       1.63        0.920000         0.690692
# ..          ...        ...        ...             ...              ...
# 751         752      98.60      97.75        5.917861         2.417366
# 752         753      90.16      90.63        5.897138         2.455065
# 753         754      93.13      90.59        5.292852         2.270979
# 754         755      91.07      86.28        4.715462         2.041258
# 755         756      80.90      76.78        4.629482         2.045446
#
#      tea_columbo  tea_kolkata  tea_mombasa  sugar_eu  sugar_us  sugar_world
# ...

# %%
#HeatMap 
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
